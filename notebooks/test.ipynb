# %%
print("Jupyter works in VS Code")
# Out:
# Jupyter works in VS Code

# %%
import requests
requests.__version__
# Out:
# '2.34.2'

# %%
data = {
    "tool": ["VS Code", "Python", "Jupyter"],
    "status": ["working", "working", "working"]
}

data
# Out:
# {'tool': ['VS Code', 'Python', 'Jupyter'],
#  'status': ['working', 'working', 'working']}
